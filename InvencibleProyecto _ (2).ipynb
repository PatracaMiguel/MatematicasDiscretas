# %% [markdown]
# # Invencible

# %% [markdown]
# ![Invencible](https://image.tmdb.org/t/p/w600_and_h900_bestv2/uCRZrXZNzzDijApmREUTFywhUmW.jpg)
#
#
# ## **Introducción**
#
# **Invincible** es una serie animada de superhéroes basada en el cómic homónimo creado por Robert Kirkman, Cory Walker y Ryan Ottley. La serie se estrenó en Amazon Prime Video y ha sido aclamada por su historia emocionante y sus intensas secuencias de acción.
#
# ## **Sinopsis**
#
# La serie sigue la vida de **Mark Grayson**, un adolescente aparentemente normal, que resulta ser el hijo del superhéroe más poderoso del planeta, **Omni-Man**. Al cumplir 17 años, Mark comienza a desarrollar sus propios poderes y asume el alias de **Invincible**. Sin embargo, pronto descubre que el legado de su padre no es tan heroico como parece, enfrentándose a desafíos que pondrán a prueba su valentía y moralidad.

# %% [markdown]
# ## Propósito del proyecto
#
# En este proyecto realizare un grafo sobre las conexiones de todos los personajes principales o que tienen un peso en la historia de las 2 temporadas

# %%
import networkx as nx
import matplotlib.pyplot as plt

Personajes = [ "Debbie Grayson", "Nolan Grayson / Omni-Man", "Art Rosenbaum", "Cecil Stedman", "Donald Ferguson", "Amber Bennett", "William Clockwell", "Olga"
              , "Theo", "Carla", "Angstrom Levy", "Markus", "Allen the Alien", "War Woman", "Green Ghost", "Red Rush", "Martian Man", "El Immortal", "Aquarus"
              , "Darkwing", "Andresa", "Lukan", "Tula", "Vidor", "general kregg", "Marcianos", "Robot", "Dupli-Kate", "Rex Splode", "Anissa", "Dr. Sísmico"
              , "Damien Darkblood", "Mark Grayson / Invincible", "Titan", "Rick", "D.A.Sinclair", "Monster girl" , "Rayo Encogedor", "Zandale Randolph / A Prueba de Balas",
              ] 

edges = [
    ("Debbie Grayson", "Nolan Grayson / Omni-Man"),
    ("Debbie Grayson", "Mark Grayson / Invincible"),
    ("Debbie Grayson", "Art Rosenbaum"),
    ("Debbie Grayson", "Cecil Stedman"),
    ("Debbie Grayson", "Donald Ferguson"),
    ("Debbie Grayson", "Amber Bennett"),
    ("Debbie Grayson", "William Clockwell"),
    ("Debbie Grayson", "Olga"),
    ("Debbie Grayson", "Theo"),
    ("Debbie Grayson", "Carla"),
    ("Debbie Grayson", "Angstrom Levy" ),
    ("Debbie Grayson", "Markus" ),
    ("Nolan Grayson / Omni-Man", "Debbie Grayson"),
    ("Nolan Grayson / Omni-Man", "Mark Grayson / Invincible"),
    ("Nolan Grayson / Omni-Man", "Cecil Stedman"),
    ("Nolan Grayson / Omni-Man", "Donald Ferguson"),
    ("Nolan Grayson / Omni-Man", "Damien Darkblood"),
    ("Nolan Grayson / Omni-Man", "Art Rosenbaum"),
    ("Nolan Grayson / Omni-Man", "Allen the Alien"),
    ("Nolan Grayson / Omni-Man", "War Woman"),
    ("Nolan Grayson / Omni-Man", "Green Ghost"),
    ("Nolan Grayson / Omni-Man", "Red Rush"),
    ("Nolan Grayson / Omni-Man", "Martian Man"),
    ("Nolan Grayson / Omni-Man", "El Immortal"),
    ("Nolan Grayson / Omni-Man", "Aquarus"),
    ("Nolan Grayson / Omni-Man", "Darkwing"),
    ("Nolan Grayson / Omni-Man", "Markus"),
    ("Nolan Grayson / Omni-Man", "Andresa"),
    ("Nolan Grayson / Omni-Man", "Lukan"),
    ("Nolan Grayson / Omni-Man", "Tula"),
    ("Nolan Grayson / Omni-Man", "Vidor"),
    ("Nolan Grayson / Omni-Man", "general kregg"),
    ("Nolan Grayson / Omni-Man", "Marcianos"),
    ("Mark Grayson / Invincible", "Debbie Grayson"),
    ("Mark Grayson / Invincible", "Nolan Grayson / Omni-Man"),
    ("Mark Grayson / Invincible", "Amber Bennett"),
    ("Mark Grayson / Invincible", "William Clockwell"),
    ("Mark Grayson / Invincible", "Atom Eve"),
    ("Mark Grayson / Invincible", "Rex Splode"),
    ("Mark Grayson / Invincible", "Dupli-Kate"),
    ("Mark Grayson / Invincible", "Robot"),
    ("Mark Grayson / Invincible", "Cecil Stedman"),
    ("Mark Grayson / Invincible", "Allen the Alien"),
    ("Mark Grayson / Invincible", "Titan"),
    ("Mark Grayson / Invincible", "Battle Beast"),
    ("Mark Grayson / Invincible", "Damien Darkblood"),
    ("Mark Grayson / Invincible", "Dr. Sísmico"),
    ("Mark Grayson / Invincible", "Markus"),
    ("Mark Grayson / Invincible", "Andresa"),
    ("Mark Grayson / Invincible", "Lukan"),
    ("Mark Grayson / Invincible", "Tula"),
    ("Mark Grayson / Invincible", "Vidor"),
    ("Mark Grayson / Invincible", "general kregg"),
    ("Mark Grayson / Invincible", "Anissa"),
    ("Mark Grayson / Invincible", "Samson Negro"),
    ("Mark Grayson / Invincible", "ganster"),
    ("Mark Grayson / Invincible", "Rudy Conners"),
    ("Mark Grayson / Invincible", "Angstrom Levy" ),
    ("Mark Grayson / Invincible", "Los Gemelos Mauler"),
    ("Mark Grayson / Invincible", "Zandale Randolph / A Prueba de Balas"),
    ("Mark Grayson / Invincible", "Rayo Encogedor"),
    ("Mark Grayson / Invincible", "Monster girl" ),
    ("Mark Grayson / Invincible", "Art Rosenbaum"),
    ("Mark Grayson / Invincible", "Martian Man 2"),
    ("Mark Grayson / Invincible", "D.A.Sinclair"),
    ("Mark Grayson / Invincible", "Rick"),
    ("Mark Grayson / Invincible", "Marcianos"),
    ("Atom Eve", "Mark Grayson / Invincible"),
    ("Atom Eve", "William Clockwell"),
    ("Atom Eve", "Rex Splode"),
    ("Atom Eve", "Amber Bennett"),
    ("Atom Eve", "Dr. Sísmico"),
    ("Atom Eve", "Samson Negro"),
    ("Atom Eve", "Dupli-Kate"),
    ("Atom Eve", "Rudy Conners"),
    ("Atom Eve", "Cecil Stedman"),
    ("Atom Eve", "Robot"),
    ("Atom Eve", "Debbie Grayson"),
    ("Atom Eve", "Zandale Randolph / A Prueba de Balas"),
    ("Atom Eve", "Monster girl" ),
    ("Atom Eve", "El Immortal"),
    ("Atom Eve", "Martian Man 2"),
    ("Atom Eve", "Marcianos"),
    ("Atom Eve", "Rayo Encogedor"),
    ("Cecil Stedman", "Nolan Grayson / Omni-Man"),
    ("Cecil Stedman", "Debbie Grayson"),
    ("Cecil Stedman", "Mark Grayson / Invincible"),
    ("Cecil Stedman", "Rex Splode"),
    ("Cecil Stedman", "Robot"),
    ("Cecil Stedman", "Samson Negro"),
    ("Cecil Stedman", "El Immortal"),
    ("Cecil Stedman", "Damien Darkblood"),
    ("Cecil Stedman", "Dupli-Kate"),
    ("Cecil Stedman", "Donald Ferguson"),
    ("Cecil Stedman", "Zandale Randolph / A Prueba de Balas"),
    ("Cecil Stedman", "War Woman "),
    ("Cecil Stedman", "Green Ghost"),
    ("Cecil Stedman", "Aquarus"),
    ("Cecil Stedman", "Red Rush"),
    ("Cecil Stedman", "Darkwing"),
    ("Cecil Stedman", "Martian Man"),
    ("Cecil Stedman", "Rayo Encogedor"),
    ("Cecil Stedman", "Monster girl" ),
    ("Cecil Stedman", "D.A.Sinclair"),
    ("William Clockwell", "Mark Grayson / Invincible"),
    ("William Clockwell", "Nolan Grayson / Omni-Man"),
    ("William Clockwell", "Atom Eve"),
    ("William Clockwell", "Amber Bennett"),
    ("William Clockwell", "D.A.Sinclair"),
    ("William Clockwell", "Debbie Grayson"),
    ("William Clockwell", "Rick"),
    ("Amber Bennett", "Mark Grayson / Invincible"),
    ("Amber Bennett", "William Clockwell"),
    ("Amber Bennett", "Atom Eve"),
    ("Amber Bennett", "Rick"),
    ("Amber Bennett", "D.A.Sinclair"),
    ("Amber Bennett", "Debbie Grayson"),
    ("Robot", "Mark Grayson / Invincible"),
    ("Robot", "Atom Eve"),
    ("Robot", "Rex Splode"),
    ("Robot", "Los Gemelos Mauler"),
    ("Robot", "Dupli-Kate"),
    ("Robot", "Donald Ferguson"),
    ("Robot", "Samson Negro"),
    ("Robot", "Cecil Stedman"),
    ("Robot", "Zandale Randolph / A Prueba de Balas"),
    ("Robot", "Monster girl" ),
    ("Robot", "El Immortal"),
    ("Robot", "Martian Man 2"),
    ("Robot", "Marcianos"),
    ("Robot", "Battle Beast"),
    ("Robot", "Rayo Encogedor"),
    ("Robot", "ganster"),
    ("Allen el Alien", "Mark Grayson / Invincible"),
    ("Allen el Alien", "Nolan Grayson / Omni-Man"),
    ("Allen el Alien", "Thaus"),
    ("Allen el Alien", "El Inmortal"),
    ("Rex Splode", "Mark Grayson / Invincible"),
    ("Rex Splode", "Atom Eve"),
    ("Rex Splode", "Robot"),
    ("Rex Splode", "Los Gemelos Mauler"),
    ("Rex Splode", "Dupli-Kate"),
    ("Rex Splode", "Donald Ferguson"),
    ("Rex Splode", "Samson Negro"),
    ("Rex Splode", "Cecil Stedman"),
    ("Rex Splode", "Zandale Randolph / A Prueba de Balas"),
    ("Rex Splode", "Monster girl" ),
    ("Rex Splode", "El Immortal"),
    ("Rex Splode", "Martian Man 2"),
    ("Rex Splode", "Marcianos"),
    ("Rex Splode", "Battle Beast"),
    ("Rex Splode", "Rayo Encogedor"),
    ("Rex Splode", "ganster"),
    ("Rex Splode", "Rudy Conners"),
    ("Samson Negro", "Mark Grayson / Invincible"),
    ("Samson Negro", "Atom Eve"),
    ("Samson Negro", "Robot"),
    ("Samson Negro", "Los Gemelos Mauler"),
    ("Samson Negro", "Dupli-Kate"),
    ("Samson Negro", "Donald Ferguson"),
    ("Samson Negro", "Rex Splode"),
    ("Samson Negro", "Cecil Stedman"),
    ("Samson Negro", "Zandale Randolph / A Prueba de Balas"),
    ("Samson Negro", "Monster girl" ),
    ("Samson Negro", "El Immortal"),
    ("Samson Negro", "Martian Man 2"),
    ("Samson Negro", "Marcianos"),
    ("Samson Negro", "Battle Beast"),
    ("Samson Negro", "Rayo Encogedor"),
    ("Samson Negro", "ganster"),
    ("Samson Negro", "Rudy Conners"),
    ("El Immortal", "Mark Grayson / Invincible"),
    ("El Immortal", "Atom Eve"),
    ("El Immortal", "Robot"),
    ("El Immortal", "Dupli-Kate"),
    ("El Immortal", "Donald Ferguson"),
    ("El Immortal", "Rex Splode"),
    ("El Immortal", "Cecil Stedman"),
    ("El Immortal", "Zandale Randolph / A Prueba de Balas"),
    ("El Immortal", "Monster girl" ),
    ("El Immortal", "Samson Negro"),
    ("El Immortal", "Martian Man 2"),
    ("El Immortal", "Marcianos"),
    ("El Immortal", "Battle Beast"),
    ("El Immortal", "Rayo Encogedor"),
    ("El Immortal", "ganster"),
    ("El Immortal", "Rudy Conners"),
    ("El Inmortal", "War Woman"),
    ("El Inmortal", "Green Ghost"),
    ("El Inmortal", "Red Rush"),
    ("El Inmortal", "Martian Man"),
    ("El Inmortal", "Nolan Grayson / Omni-Man"),
    ("El Inmortal", "Aquarus"),
    ("El Inmortal", "Darkwing"),
    ("El Inmortal", "Los Gemelos Mauler"),
    ("Damien Darkblood", "Mark Grayson / Invincible"),
    ("Damien Darkblood", "Nolan Grayson / Omni-Man"),
    ("Damien Darkblood", "Debbie Grayson"),
    ("Damien Darkblood", "Cecil Stedman"),
    ("Damien Darkblood", "Donald Ferguson"),
    ("Los Gemelos Mauler", "War Woman"),
    ("Los Gemelos Mauler", "Green Ghost"),
    ("Los Gemelos Mauler", "Red Rush"),
    ("Los Gemelos Mauler", "Martian Man"),
    ("Los Gemelos Mauler", "El Immortal"),
    ("Los Gemelos Mauler", "Aquarus"),
    ("Los Gemelos Mauler", "Darkwing"),
    ("Los Gemelos Mauler", "Mark Grayson / Invincible"),
    ("Los Gemelos Mauler", "Robot"),
    ("Los Gemelos Mauler", "Rudy Conners"),
    ("Los Gemelos Mauler", "Angstrom Levy"),
    ("Dr. Sísmico", "Mark Grayson / Invincible"),     
    ("Dr. Sísmico", "Atom Eve"),
    ("Dupli-Kate", "Mark Grayson / Invincible"),
    ("Dupli-Kate", "Atom Eve"),
    ("Dupli-Kate", "Robot"),
    ("Dupli-Kate", "Los Gemelos Mauler"),
    ("Dupli-Kate", "El inmortal"),
    ("Dupli-Kate", "Donald Ferguson"),
    ("Dupli-Kate", "Rex Splode"),
    ("Dupli-Kate", "Cecil Stedman"),
    ("Dupli-Kate", "Zandale Randolph / A Prueba de Balas"),
    ("Dupli-Kate", "Monster girl"),
    ("Dupli-Kate", "Samson Negro"),
    ("Dupli-Kate", "Martian Man 2"),
    ("Dupli-Kate", "Marcianos"),
    ("Dupli-Kate", "Battle Beast"),
    ("Dupli-Kate", "Rayo Encogedor"),
    ("Dupli-Kate", "ganster"),
    ("Dupli-Kate", "Rudy Conners"),
    ("Titán", "Mark Grayson / Invincible"),
    ("Titán", "Atom Eve"),
    ("Titán", "Robot"),
    ("Titán", "Dupli-Kate"),
    ("Titán", "Rex Splode"),
    ("Titán", "Monster girl"),
    ("Titán", "Samson Negro"),
    ("Titán", "Battle Beast"),
    ("Titán", "Rayo Encogedor"),
    ("Titán", "ganster"),
    ("Titán", "Rudy Conners"),
    ("Battle Beast", "Titán"),
    ("Battle Beast", "ganster"),
    ("Battle Beast", "Mark Grayson / Invincible"),
    ("Battle Beast", "Atom Eve"),
    ("Battle Beast", "Robot"),
    ("Battle Beast", "Dupli-Kate"),
    ("Battle Beast", "Rex Splode"),
    ("Battle Beast", "Monster girl"),
    ("Battle Beast", "Samson Negro"),
    ("Battle Beast", "Rudy Conners"),
    ("Battle Beast", "Rayo Encogedor"),
    ("Art Rosenbaum", "Mark Grayson / Invincible"),
    ("Art Rosenbaum", "Nolan Grayson / Omni-Man"),
    ("Art Rosenbaum", "Debbie Grayson"),
    ("Donald Ferguson", "Nolan Grayson / Omni-Man"),
    ("Donald Ferguson", "Debbie Grayson"),
    ("Donald Ferguson", "Mark Grayson / Invincible"),
    ("Donald Ferguson", "William Clockwell"),
    ("Donald Ferguson", "Rex Splode"),
    ("Donald Ferguson", "Robot"),
    ("Donald Ferguson", "Rex Splode"),
    ("Donald Ferguson", "Samson Negro"),
    ("Donald Ferguson", "El Inmortal"),
    ("Donald Ferguson", "Damien Darkblood"),
    ("Donald Ferguson", "Dupli-Kate"),
    ("Donald Ferguson", "Cecil Stedman"),
    ("Donald Ferguson", "Zandale Randolph / A Prueba de Balas"),
    ("Donald Ferguson", "War Woman"),
    ("Donald Ferguson", "Green Ghost"),
    ("Donald Ferguson", "Aquarus"),
    ("Donald Ferguson", "Red Rush"),
    ("Donald Ferguson", "Darkwing"),
    ("Donald Ferguson", "Martian Man"),
    ("Donald Ferguson", "Rayo Encogedor"),
    ("Donald Ferguson", "Monster girl"),
    ("Donald Ferguson", "D.A.Sinclair"),
    ("Rudy Conners", "Mark Grayson / Invincible"),
    ("Rudy Conners", "Atom Eve"),
    ("Rudy Conners", "Robot"),
    ("Rudy Conners", "Los Gemelos Mauler"),
    ("Rudy Conners", "Dupli-Kate"),
    ("Rudy Conners", "Rex Splode"),
    ("Rudy Conners", "Monster girl"),
    ("Rudy Conners", "Samson Negro"),
    ("Rudy Conners", "Cecil Stedman"),
    ("Rudy Conners", "Zandale Randolph / A Prueba de Balas"),
    ("Rudy Conners", "Martian Man 2"),
    ("Rudy Conners", "Marcianos"),
    ("Rudy Conners", "Battle Beast"),
    ("Rudy Conners", "Rayo Encogedor"),
    ("Rudy Conners", "ganster"),
    ("Rudy Conners", "Red Rush"),
    ("Rudy Conners", "Darkwing"),
    ("Rudy Conners", "Aquarus"),
    ("Rudy Conners", "Monster girl"),
    ("Rudy Conners", "D.A.Sinclair"),
    ("Rudy Conners", "El Inmortal"),
    ("Angstrom Levy", "Mark Grayson / Invincible"),
    ("Angstrom Levy", "Debbie Grayson"),
    ("Angstrom Levy", "Nolan Grayson / Omni-Man"),
    ("Angstrom Levy", "Cecil Stedman"),
    ("Angstrom Levy", "Donald Ferguson"),
    ("Angstrom Levy", "Damien Darkblood"),
    ("Angstrom Levy", "D.A.Sinclair"),
    ("Los Marcianos", "Nolan Grayson / Omni-Man"),
    ("Los Marcianos", "Mark Grayson / Invincible"),
    ("Los Marcianos", "El Inmortal"),
    ("Los Marcianos", "Allen el Alien"),
    ("Los Marcianos", "Nolan Grayson / Omni-Man"),
    ("Los Marcianos", "Angstrom Levy"),
    ("Los Marcianos", "Rudy Conners"),
    ("Ganster", "Mark Grayson / Invincible"),
    ("Ganster", "Nolan Grayson / Omni-Man"),
    ("Ganster", "El Immortal"),
    ("Ganster", "Allen el Alien"),
    ("Ganster", "Nolan Grayson / Omni-Man"),
    ("Ganster", "Angstrom Levy"),
    ("Ganster", "Rudy Conners"),
]



G = nx.Graph()
G.add_nodes_from(Personajes)
G.add_edges_from(edges)

plt.figure(figsize=(30, 40))
pos = nx.spring_layout(G, k=0.3)  


nx.draw_networkx_nodes(G, pos, node_size=500, node_color='skyblue')
nx.draw_networkx_edges(G, pos, edgelist=edges, edge_color='gray')
nx.draw_networkx_labels(G, pos, font_size=10, font_family="sans-serif")

plt.title("Relaciones entre personajes en Invincible")
plt.show()

# %% [markdown]
# ## Grado de los nodos

# %%
degree_dict = dict(G.degree())
print("Grado de los nodos:", degree_dict)
print("\n")
# Out:
# Grado de los nodos: {'Debbie Grayson': 14, 'Nolan Grayson / Omni-Man': 27, 'Art Rosenbaum': 3, 'Cecil Stedman': 23, 'Donald Ferguson': 23, 'Amber Bennett': 6, 'William Clockwell': 8, 'Olga': 1, 'Theo': 1, 'Carla': 1, 'Angstrom Levy': 10, 'Markus': 3, 'Allen the Alien': 2, 'War Woman': 4, 'Green Ghost': 5, 'Red Rush': 6, 'Martian Man': 5, 'El Immortal': 19, 'Aquarus': 6, 'Darkwing': 6, 'Andresa': 2, 'Lukan': 2, 'Tula': 2, 'Vidor': 2, 'general kregg': 2, 'Marcianos': 9, 'Robot': 18, 'Dupli-Kate': 19, 'Rex Splode': 18, 'Anissa': 1, 'Dr. Sísmico': 2, 'Damien Darkblood': 6, 'Mark Grayson / Invincible': 40, 'Titan': 1, 'Rick': 3, 'D.A.Sinclair': 7, 'Monster girl': 12, 'Rayo Encogedor': 12, 'Zandale Randolph / A Prueba de Balas': 10, 'Atom Eve': 19, 'Battle Beast': 12, 'Samson Negro': 18, 'ganster': 9, 'Rudy Conners': 24, 'Los Gemelos Mauler': 15, 'Martian Man 2': 8, 'War Woman ': 1, 'Allen el Alien': 6, 'Thaus': 1, 'El Inmortal': 12, 'El inmortal': 1, 'Titán': 11, 'Los Marcianos': 6, 'Gans
# ...

# %% [markdown]
# ## Peso de los nodos

# %%
node_weights = {node: degree for node, degree in degree_dict.items()}
print("Peso de los nodos:", node_weights)
print("\n")
# Out:
# Peso de los nodos: {'Debbie Grayson': 14, 'Nolan Grayson / Omni-Man': 27, 'Art Rosenbaum': 3, 'Cecil Stedman': 23, 'Donald Ferguson': 23, 'Amber Bennett': 6, 'William Clockwell': 8, 'Olga': 1, 'Theo': 1, 'Carla': 1, 'Angstrom Levy': 10, 'Markus': 3, 'Allen the Alien': 2, 'War Woman': 4, 'Green Ghost': 5, 'Red Rush': 6, 'Martian Man': 5, 'El Immortal': 19, 'Aquarus': 6, 'Darkwing': 6, 'Andresa': 2, 'Lukan': 2, 'Tula': 2, 'Vidor': 2, 'general kregg': 2, 'Marcianos': 9, 'Robot': 18, 'Dupli-Kate': 19, 'Rex Splode': 18, 'Anissa': 1, 'Dr. Sísmico': 2, 'Damien Darkblood': 6, 'Mark Grayson / Invincible': 40, 'Titan': 1, 'Rick': 3, 'D.A.Sinclair': 7, 'Monster girl': 12, 'Rayo Encogedor': 12, 'Zandale Randolph / A Prueba de Balas': 10, 'Atom Eve': 19, 'Battle Beast': 12, 'Samson Negro': 18, 'ganster': 9, 'Rudy Conners': 24, 'Los Gemelos Mauler': 15, 'Martian Man 2': 8, 'War Woman ': 1, 'Allen el Alien': 6, 'Thaus': 1, 'El Inmortal': 12, 'El inmortal': 1, 'Titán': 11, 'Los Marcianos': 6, 'Ganst
# ...

# %% [markdown]
# ## Distancia entre los nodos

# %%
shortest_path_lengths = dict(nx.all_pairs_shortest_path_length(G))

print("Distancias entre todos los pares de nodos:")
for node, distances in shortest_path_lengths.items():
    print(f"{node}: {distances}")
    print("\n")
# Out:
# Distancias entre todos los pares de nodos:
# ...

# %% [markdown]
# ## Exentricidad del grafo

# %%
node_eccentricity = nx.eccentricity(G)
print("Excentricidad de los nodos:", node_eccentricity)
print("\n")
# Out:
# Excentricidad de los nodos: {'Debbie Grayson': 3, 'Nolan Grayson / Omni-Man': 3, 'Art Rosenbaum': 3, 'Cecil Stedman': 3, 'Donald Ferguson': 3, 'Amber Bennett': 3, 'William Clockwell': 3, 'Olga': 4, 'Theo': 4, 'Carla': 4, 'Angstrom Levy': 3, 'Markus': 3, 'Allen the Alien': 3, 'War Woman': 3, 'Green Ghost': 3, 'Red Rush': 3, 'Martian Man': 3, 'El Immortal': 3, 'Aquarus': 3, 'Darkwing': 3, 'Andresa': 3, 'Lukan': 3, 'Tula': 3, 'Vidor': 3, 'general kregg': 3, 'Marcianos': 3, 'Robot': 3, 'Dupli-Kate': 3, 'Rex Splode': 3, 'Anissa': 3, 'Dr. Sísmico': 3, 'Damien Darkblood': 3, 'Mark Grayson / Invincible': 2, 'Titan': 3, 'Rick': 3, 'D.A.Sinclair': 3, 'Monster girl': 3, 'Rayo Encogedor': 3, 'Zandale Randolph / A Prueba de Balas': 3, 'Atom Eve': 3, 'Battle Beast': 3, 'Samson Negro': 3, 'ganster': 3, 'Rudy Conners': 3, 'Los Gemelos Mauler': 3, 'Martian Man 2': 3, 'War Woman ': 4, 'Allen el Alien': 3, 'Thaus': 4, 'El Inmortal': 3, 'El inmortal': 4, 'Titán': 3, 'Los Marcianos': 3, 'Ganster': 3}

# %% [markdown]
# ## Radio del grafo

# %%
graph_radius = nx.radius(G)
print("Radio del grafo:", graph_radius)
print("\n")
# Out:
# Radio del grafo: 2

# %% [markdown]
# ## Diámetro del grafo

# %%
graph_diameter = nx.diameter(G)
print("Diámetro del grafo:", graph_diameter)
print("\n")
# Out:
# Diámetro del grafo: 4

# %% [markdown]
# ## Centro del grafo

# %%
graph_center = nx.center(G)
print("Centro del grafo:", graph_center)
print("\n")
# Out:
# Centro del grafo: ['Mark Grayson / Invincible']

# %% [markdown]
# ## Periferia

# %%
graph_periphery = nx.periphery(G)
print("Periferia del grafo:", graph_periphery)
print("\n")
# Out:
# Periferia del grafo: ['Olga', 'Theo', 'Carla', 'War Woman ', 'Thaus', 'El inmortal']

# %% [markdown]
# ## Camino  simple

# %%
def tiene_camino_simple(graph):
    # Un grafo tiene un camino simple si todos los pares de nodos tienen una distancia menor o igual a 2
    for node, distances in shortest_path_lengths.items():
        if any(distance > 2 for distance in distances.values()):
            return False
    return True

print(f"Tiene camino simple: {tiene_camino_simple(G)}")
# Out:
# Tiene camino simple: False

# %% [markdown]
# ## Camino y circuito Eureliano

# %%
def tiene_camino_euleriano(graph):
    for node in graph.nodes():
        if graph.degree(node) % 2 != 0:
            return False
    return nx.is_connected(graph)


def tiene_circuito_euleriano(graph):
    if not tiene_camino_euleriano(graph):
        return False
    return len([node for node in graph.nodes() if graph.degree(node) > 0]) == graph.number_of_nodes()


print(f"Tiene camino euleriano: {tiene_camino_euleriano(G)}")
print(f"Tiene circuito euleriano: {tiene_circuito_euleriano(G)}")
# Out:
# Tiene camino euleriano: False
# Tiene circuito euleriano: False

# %% [markdown]
# ## Camino y circuito Hamiltoniano

# %%
def tiene_camino_hamiltoniano(graph):
    for node, distances in shortest_path_lengths.items():
        if any(distance > 1 for distance in distances.values()):
            return False
    return True


def tiene_ciclo_hamiltoniano(graph):
    if not tiene_camino_hamiltoniano(graph):
        return False
    for node in graph.nodes():
        neighbors = list(graph.neighbors(node))
        if len(neighbors) >= 2:
            return True
    return False

print(f"Tiene camino hamiltoniano: {tiene_camino_hamiltoniano(G)}")
print(f"Tiene ciclo hamiltoniano: {tiene_ciclo_hamiltoniano(G)}")
# Out:
# Tiene camino hamiltoniano: False
# Tiene ciclo hamiltoniano: False

# %% [markdown]
# ## Referencias

# %%
Introducción a grafos y redes con Python. (s. f.). https://cienciadedatos.net/documentos/pygml01-introduccion-grafos-redes-python.html 
Wiki, C. T. I. (s. f.). Personajes. Invincible Wiki. https://invincible.fandom.com/es/wiki/Categor%C3%ADa:Personajes
